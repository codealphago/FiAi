# %%
# coding: utf-8
import tushare as ts
import easytrader as trade
from easytrader import helpers
import pandas as pd
import datetime as dt
import time
from mercury import utils
from mercury import uqer
pd.options.display.max_columns = 100
pd.options.display.max_rows = 300

#优矿token token ='5fa4680adf1c779e93f1d90880b4e2f55a52a7704f2408565ca8c12eebba0469'
#sess = uqer.Client(token='5fa4680adf1c779e93f1d90880b4e2f55a52a7704f2408565ca8c12eebba0469')

yjb = trade.use('yjb')
yjb.prepare('./guojin.json')

## 获取资产情况 
balance = yjb.balance
## 获取股票持仓
position = yjb.position
balance
# Out:
# 2016-11-29 14:20:36,545 [DEBUG] yjbtrader.py 56: verify code detect result: 0529
# 2016-11-29 14:20:36,755 [DEBUG] yjbtrader.py 77: login response: {"login_type":"stock","returnJson":"{function_id: '200', redirect_url: '..\/main.jsp', msg_info: '', msg_no: '0', error_grids: '', grid_count: '2', CSRF_Token:'NTAwNTE2MDUwNDk3MDgwMzI5Ny03MjcwOTUzMTk5Njk1MDY5OTk0', Func200: [{company_name: '公司名称', init_date: '发生日期', sys_status: '系统状态', content_type: '帐号校验方式', account_content: '输入内容', branch_no: '客户网点', client_id: '客户号', client_name: '客户姓名', corp_client_group: '', fundaccount_count: '资产账号个数', fund_account: '资金帐号', client_rights: '客户权限', sysnode_id: '', message_flag: '消息标志', user_token: '', last_login_date: '', last_login_time: '', last_op_entrust_way: '上次登陆委托方式', last_op_station: '上次登陆站点\/电话', error_no: '错误号', error_info: '错误原因', money_count: '币种个数', money_type: '币种', square_flag: '结算标示', enable_balance: '可用金额', current_balance: '当前余额', bank_no: '银行代码', exchange_type: '交易类别', stock_account: '证券账号', bank_trans_flag: '银行转帐允许标志', initpasswd_flag: '初始密码标志', last_date: '上一交易日', last_op_ip: '上次登陆IP地址', online_time: '在线时间', remark: '摘要', tabconfirm_flag: '强制帐单确认', prestore_info: '', login_times: '登录次数', asset_prop: '', product_flag: '', corp_risk_level: '', corp_end_date: '', valid_flag: '', session_no: '', foreign_flag: '', branch_name: '', next_token: '', safety_devbound: '', safety_device_bound: '', safety_restricted_action: '', safety_restricted_info: '', alert_info: '', asset_type: '资产账号类别', password_errors: '', F800_auth_id: '', F800_en_resource_no: '', F800_en_resource_str: '', F800_app_user_id: '', F800_grantticket_id: '', F800_warn_no: '', F800_warn_info: '', F800_last_region_name: '', UserParam2: '', UserParam1: '', login_date: '上次登录日期', login_time: '上次登录时刻'},{company_name: '国金证券股份有限公司', init_date: '20161129', sys_status: '1', content_type: '0', account_content: '', branch_no: '33', client_id: '40533476', client_name: '徐雷明', corp_client_group: '1', fundaccount_count: '0', fund_account: '40533476', client_rights: 'CWdetabo', sysnode_id: '2', message_flag: '0', user_token: 'P4mJoUBDS4rMGLBR2hMjJlG3rZYlBogUeH5+', last_login_date: '20161129', last_login_time: '132911', last_op_entrust_way: '无线委托', last_op_station: 'PC,LIP:192.168.31.150;IIP:124.126.129.91;MAC:681729E17A9E;HD:DWW-DXE133WSPS;PCN:DELL-RAY;CPU:bfebfbff000306a9-GenuineIntel;PI:C:,NTFS,100G@TDXPC;CliVer:7.17.0', error_no: '0', error_info: '', money_count: '1', money_type: '0', square_flag: '2', enable_balance: '62734.02', current_balance: '25042.01', bank_no: '7', exchange_type: '0', stock_account: '', bank_trans_flag: ' ', initpasswd_flag: ' ', last_date: '0', last_op_ip: ' ', online_time: '0', remark: ' ', tabconfirm_flag: ' ', prestore_info: ' ', login_times: '1086', asset_prop: '0', product_flag: '0', corp_risk_level: '4', corp_end_date: '20181127', valid_flag: '0', session_no: '0', foreign_flag: ' ', branch_name: '', next_token: '0', safety_devbound: '0000', safety_device_bound: '0000', safety_restricted_action: '0000', safety_restricted_info: '<ETX><ETX><ETX><ETX>', alert_info: '', asset_type: '0', password_errors: '-1', F800_auth_id: '', F800_en_resource_no: '', F800_en_resource_str: '', F800_app_user_id: '', F800_grantticket_id: '', F800_warn_no: '', F800_warn_info: '', F800_last_region_name: '', UserParam2: '2', UserParam1: 'P4mJoUBDS4rMGLBR2hMjJlG3rZYlBogUeH5+', login_date: '20161129', login_time: '132911'}], end: '0' }"}
# [{'asset_balance': 491535.33,
#   'current_balance': 25042.01,
#   'enable_balance': 62734.02,
#   'market_value': 428801.23,
#   'money_type': '人民币',
#   'pre_interest': '1.880'}]

# %%
file_name = 'newissue2.csv'  
newissue = pd.DataFrame()

newissue = newissue.from_csv(file_name,parse_dates = False)
newissue.index = newissue.ticker.apply(lambda x:x[2:8]).values
newissue['open_price'] = newissue.price.apply(lambda x: round(x * 1.1,2))
print(newissue)

def delayrun(): # 线程运行函数 
    for s in newissue.index:
        print(s,newissue.loc[s,'open_price'], 100)
        info = yjb.buy(s, price=newissue.loc[s,'open_price'], amount=100)
        print (info)        
# t = Timer(timer_interval,delayrun)  
# t.start()  
#while (f_time >= 9.15 and f_time <= 10.30) :  
icount = 0 
flag = True
while icount < 2 and flag == True:
    c_time = dt.datetime.now().strftime('%H.%M%S%f')
    f_time = float(c_time)
    print ("now time is : " , f_time)
    if f_time > 9.1503 :
        flag = False
    elif f_time >= 9.1457 : 
        delayrun()
        icount += 1
    time.sleep(2) 

print('Market is closed...' ,dt.datetime.now() )
# Out:
#           ticker  price  open_price
# 603987  sh603987  13.68       15.05
# 002820  sz002820  26.29       28.92
# 002821  sz002821  48.36       53.20
# now time is :  9.12553796
# now time is :  9.1257379569
# now time is :  9.1259389562
# now time is :  9.1301402806
# now time is :  9.1303414109
# now time is :  9.1305417522
# now time is :  9.130741891
# now time is :  9.1309421096
# now time is :  9.1311430374
# now time is :  9.1313430492
# now time is :  9.1315431166
# now time is :  9.1317431924
# now time is :  9.1319433318
# now time is :  9.1321434369
# now time is :  9.1323435934
# now time is :  9.1325437217
# now time is :  9.1327438334
# now time is :  9.1329438846
# now time is :  9.1331440073
# now time is :  9.1333442866
# now time is :  9.133544371
# now time is :  9.1337444657
# now time is :  9.1339445817
# now time is :  9.1341446757
# now time is :  9.1343447231
# now time is :  9.1345449684
# now time is :  9.134745233
# now time is :  9.1349453765
# now time is :  9.1351455012
# now time is :  9.1353458367
# now time is :  9.1355459571
# now time is :  9.1357460791
# now time is :  9.1359462068
# now time is :  9.1401463101
# now time is :  9.1403464368
# now time is :  9.1405465335
# now time is :  9.1407467083
# now time is :  9.1409468147
# now time is :  9.1411469428
# now time is :  9.1413471117
# now time is :  9.1415472812
# now time is :  9.1417478162
# now time is :  9.1419479519
# now time is :  9.1421480673
# now time is :  9.1423482057
# now time is :  9.1425484587
# now time is :  9.1427488478
# now time is :  9.1429488707
# now time is :  9.143148968
# now time is :  9.1433490684
# now time is :  9.1435491677
# now time is :  9.1437492512
# now time is :  9.1439494017
# now time is :  9.144149515
# now time is :  9.1443496139
# now time is :  9.1445497136
# now time is :  9.1447498513
# now time is :  9.1449500305
# now time is :  9.1451500978
# now time is :  9.145350234
# now time is :  9.1455503652
# now time is :  9.1457505346
# 603987 15.05 100
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py", line 595, in urlopen
#     chunked=chunked)
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py", line 393, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py", line 389, in _make_request
#     httplib_response = conn.getresponse()
#   File "E:\workspace\pythonSpace\anaconda\lib\http\client.py", line 1174, in getresponse
#     response.begin()
#   File "E:\workspace\pythonSpace\anaconda\lib\http\client.py", line 282, in begin
#     version, status, reason = self._read_status()
#   File "E:\workspace\pythonSpace\anaconda\lib\http\client.py", line 243, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "E:\workspace\pythonSpace\anaconda\lib\socket.py", line 571, in readinto
#     return self._sock.recv_into(b)
#   File "E:\workspace\pythonSpace\anaconda\lib\ssl.py", line 924, in recv_into
#     return self.read(nbytes, buffer)
#   File "E:\workspace\pythonSpace\anaconda\lib\ssl.py", line 786, in read
#     return self._sslobj.read(len, buffer)
#   File "E:\workspace\pythonSpace\anaconda\lib\ssl.py", line 570, in read
#     v = self._sslobj.read(len, buffer)
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\adapters.py", line 423, in send
#     timeout=timeout
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py", line 640, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\util\retry.py", line 261, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\packages\six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py", line 595, in urlopen
#     chunked=chunked)
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py", line 393, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py", line 389, in _make_request
#     httplib_response = conn.getresponse()
#   File "E:\workspace\pythonSpace\anaconda\lib\http\client.py", line 1174, in getresponse
#     response.begin()
#   File "E:\workspace\pythonSpace\anaconda\lib\http\client.py", line 282, in begin
#     version, status, reason = self._read_status()
#   File "E:\workspace\pythonSpace\anaconda\lib\http\client.py", line 243, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "E:\workspace\pythonSpace\anaconda\lib\socket.py", line 571, in readinto
#     return self._sock.recv_into(b)
#   File "E:\workspace\pythonSpace\anaconda\lib\ssl.py", line 924, in recv_into
#     return self.read(nbytes, buffer)
#   File "E:\workspace\pythonSpace\anaconda\lib\ssl.py", line 786, in read
#     return self._sslobj.read(len, buffer)
#   File "E:\workspace\pythonSpace\anaconda\lib\ssl.py", line 570, in read
#     v = self._sslobj.read(len, buffer)
# requests.packages.urllib3.exceptions.ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\workspace\pythonSpace\anaconda\lib\threading.py", line 923, in _bootstrap_inner
#     self.run()
#   File "E:\workspace\pythonSpace\anaconda\lib\threading.py", line 871, in run
#     self._target(*self._args, **self._kwargs)
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\easytrader-0.8.1-py3.5.egg\easytrader\webtrader.py", line 96, in send_heartbeat
#     self.autologin()
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\easytrader-0.8.1-py3.5.egg\easytrader\webtrader.py", line 67, in autologin
#     if self.login():
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\easytrader-0.8.1-py3.5.egg\easytrader\yjbtrader.py", line 35, in login
#     self.s.get(self.config['login_page'])
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\sessions.py", line 488, in get
#     return self.request('GET', url, **kwargs)
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\sessions.py", line 475, in request
#     resp = self.send(prep, **send_kwargs)
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\sessions.py", line 596, in send
#     r = adapter.send(request, **kwargs)
#   File "E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\adapters.py", line 473, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     392                     # otherwise it looks like a programming error was the cause.
# --> 393                     six.raise_from(e, None)
#     394         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     388                 try:
# --> 389                     httplib_response = conn.getresponse()
#     390                 except Exception as e:
#
# E:\workspace\pythonSpace\anaconda\lib\http\client.py in getresponse(self)
#    1173             try:
# -> 1174                 response.begin()
#    1175             except ConnectionError:
#
# E:\workspace\pythonSpace\anaconda\lib\http\client.py in begin(self)
#     281         while True:
# --> 282             version, status, reason = self._read_status()
#     283             if status != CONTINUE:
#
# E:\workspace\pythonSpace\anaconda\lib\http\client.py in _read_status(self)
#     242     def _read_status(self):
# --> 243         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     244         if len(line) > _MAXLINE:
#
# E:\workspace\pythonSpace\anaconda\lib\socket.py in readinto(self, b)
#     570             try:
# --> 571                 return self._sock.recv_into(b)
#     572             except timeout:
#
# E:\workspace\pythonSpace\anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     923                   self.__class__)
# --> 924             return self.read(nbytes, buffer)
#     925         else:
#
# E:\workspace\pythonSpace\anaconda\lib\ssl.py in read(self, len, buffer)
#     785         try:
# --> 786             return self._sslobj.read(len, buffer)
#     787         except SSLError as x:
#
# E:\workspace\pythonSpace\anaconda\lib\ssl.py in read(self, len, buffer)
#     569         if buffer is not None:
# --> 570             v = self._sslobj.read(len, buffer)
#     571         else:
#
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     639             retries = retries.increment(method, url, error=e, _pool=self,
# --> 640                                         _stacktrace=sys.exc_info()[2])
#     641             retries.sleep()
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     260             if read is False:
# --> 261                 raise six.reraise(type(error), error, _stacktrace)
#     262             elif read is not None:
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     392                     # otherwise it looks like a programming error was the cause.
# --> 393                     six.raise_from(e, None)
#     394         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     388                 try:
# --> 389                     httplib_response = conn.getresponse()
#     390                 except Exception as e:
#
# E:\workspace\pythonSpace\anaconda\lib\http\client.py in getresponse(self)
#    1173             try:
# -> 1174                 response.begin()
#    1175             except ConnectionError:
#
# E:\workspace\pythonSpace\anaconda\lib\http\client.py in begin(self)
#     281         while True:
# --> 282             version, status, reason = self._read_status()
#     283             if status != CONTINUE:
#
# E:\workspace\pythonSpace\anaconda\lib\http\client.py in _read_status(self)
#     242     def _read_status(self):
# --> 243         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     244         if len(line) > _MAXLINE:
#
# E:\workspace\pythonSpace\anaconda\lib\socket.py in readinto(self, b)
#     570             try:
# --> 571                 return self._sock.recv_into(b)
#     572             except timeout:
#
# E:\workspace\pythonSpace\anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     923                   self.__class__)
# --> 924             return self.read(nbytes, buffer)
#     925         else:
#
# E:\workspace\pythonSpace\anaconda\lib\ssl.py in read(self, len, buffer)
#     785         try:
# --> 786             return self._sslobj.read(len, buffer)
#     787         except SSLError as x:
#
# E:\workspace\pythonSpace\anaconda\lib\ssl.py in read(self, len, buffer)
#     569         if buffer is not None:
# --> 570             v = self._sslobj.read(len, buffer)
#     571         else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-65dbd1b4b5b2> in <module>()
#      25         flag = False
#      26     elif f_time >= 9.1457 :
# ---> 27         delayrun()
#      28         icount += 1
#      29     time.sleep(2)
#
# <ipython-input-2-65dbd1b4b5b2> in delayrun()
#      11     for s in newissue.index:
#      12         print(s,newissue.loc[s,'open_price'], 100)
# ---> 13         info = yjb.buy(s, price=newissue.loc[s,'open_price'], amount=100)
#      14         print (info)
#      15 # t = Timer(timer_interval,delayrun)
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\easytrader-0.8.1-py3.5.egg\easytrader\yjbtrader.py in buy(self, stock_code, price, amount, volume, entrust_prop)
#     129             entrust_amount=amount if amount else volume // price // 100 * 100
#     130         )
# --> 131         return self.__trade(stock_code, price, entrust_prop=entrust_prop, other=params)
#     132
#     133     def sell(self, stock_code, price, amount=0, volume=0, entrust_prop=0):
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\easytrader-0.8.1-py3.5.egg\easytrader\yjbtrader.py in __trade(self, stock_code, price, entrust_prop, other)
#     172         # 检查是否已经掉线
#     173         if not self.heart_thread.is_alive():
# --> 174             check_data = self.get_balance()
#     175             if type(check_data) == dict:
#     176                 return check_data
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\easytrader-0.8.1-py3.5.egg\easytrader\webtrader.py in get_balance(self)
#     121     def get_balance(self):
#     122         """获取账户资金状况"""
# --> 123         return self.do(self.config['balance'])
#     124
#     125     @property
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\easytrader-0.8.1-py3.5.egg\easytrader\webtrader.py in do(self, params)
#     180         request_params = self.create_basic_params()
#     181         request_params.update(params)
# --> 182         response_data = self.request(request_params)
#     183         try:
#     184             format_json_data = self.format_response_data(response_data)
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\easytrader-0.8.1-py3.5.egg\easytrader\yjbtrader.py in request(self, params)
#     216
#     217     def request(self, params):
# --> 218         r = self.s.get(self.trade_prefix, params=params)
#     219         return r.text
#     220
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     486
#     487         kwargs.setdefault('allow_redirects', True)
# --> 488         return self.request('GET', url, **kwargs)
#     489
#     490     def options(self, url, **kwargs):
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# E:\workspace\pythonSpace\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     471
#     472         except (ProtocolError, socket.error) as err:
# --> 473             raise ConnectionError(err, request=request)
#     474
#     475         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
