# %%
# coding: utf-8
import tushare as ts
import easytrader as trade
from easytrader import helpers
import pandas as pd
import datetime as dt
import time
from mercury import utils
from mercury import uqer
import shipane_sdk as spe
from shipane_sdk.stock import *
pd.options.display.max_columns = 100
pd.options.display.max_rows = 300

account = 'account:13810509932'
cli = spe.Client(host='localhost',port='8880')
cli.get_account(client=account)
# Out:
# '13810509932 通达信永久模拟交易 f001001001014876 通达信官方'

# %%
# cli.get_positions()
order = {
  "action": "BUY",
  "symbol" : "000001",
  "type": "LIMIT",
  "priceType" : 0,
  "price" : 9.00,
  "amount" : 100
}
# cli.buy(**order)

# %%
# 获取当天申购新股
# today = dt.date.today()
today = dt.date(2017,2,15)
tdate = today.isoformat()
print ("trade date is : " , tdate)
ipos = StockUtils.new_stocks()
ipos = ipos[(ipos.ipo_date == tdate)]
ipos
# Out:
# trade date is :  2017-02-15
#       code   xcode  name    ipo_date issue_date  price
# 11  300619  300619   金银河  2017-02-15        NaN  10.98
# 12  300617  300617  安靠智电  2017-02-15        NaN  24.38

# %%
# 获取当天上市
print ("trade date is : " , tdate)
issues = StockUtils.new_stocks()
issues = issues[(issues.issue_date == tdate)]
issues
# Out:
# trade date is :  2017-02-15
#       code   xcode  name    ipo_date  issue_date  price
# 21  300615  300615  欣天科技  2017-02-03  2017-02-15  14.37
# 22  300612  300612  宣亚国际  2017-02-03  2017-02-15  16.14
# 23  601212  780212  白银有色  2017-02-03  2017-02-15   1.78
# 24  300609  300609  汇纳科技  2017-01-26  2017-02-15   8.12

# %%
# 获取3个交易日内上市新股 不包括当天
print ("trade date is : " , tdate)
stocks = StockUtils.new_stocks()
stocks = stocks[(stocks.issue_date < tdate)]
stocks = stocks.sort_values(by='issue_date',ascending=0).head(6)
stocks
# Out:
# trade date is :  2017-02-15
#       code   xcode  name    ipo_date  issue_date  price
# 29  603839  732839  安正时尚  2017-01-24  2017-02-14  16.78
# 25  002848  002848  高斯贝尔  2017-01-26  2017-02-13   6.31
# 26  300610  300610  晨化股份  2017-01-25  2017-02-13  10.57
# 27  603330  732330  上海天洋  2017-01-25  2017-02-13  18.19
# 28  603615  732615  茶花股份  2017-01-25  2017-02-13   8.37
# 30  300608  300608   思特奇  2017-01-24  2017-02-13  16.16

# %%
file_name = 'newissue_sh.csv'  
# newissue = pd.DataFrame()
# newissue = newissue.from_csv(file_name,parse_dates = False)
# newissue.index = newissue.ticker.apply(lambda x:x[2:8]).values
# newissue['open_price'] = newissue.price.apply(lambda x: round(x * 1.20 *1.20,2))
print(newissue)

def delayrun(): # 线程运行函数 
    for s in newissue.index:
        print(s,newissue.loc[s,'open_price'], 100)
        info = yjb.buy(s, price=newissue.loc[s,'open_price'], amount=100)
        print (info)
        pass
        
# t = Timer(timer_interval,delayrun)  
# t.start()  
#while (f_time >= 9.15 and f_time <= 10.30) :  
icount = 0 
flag = True
while icount < 2 and flag == True:
    c_time = dt.datetime.now().strftime('%H.%M%S%f')
    f_time = float(c_time)
    print ("now time is : " , f_time)
    if f_time > 9.3002 : 
        flag = False
    elif f_time > 9.2957 :
        delayrun()
        icount += 1
    time.sleep(2) 

print('Market is closed...' ,dt.datetime.now() )
# Out:
#           ticker  price  open_price
# 300565  sz300565   8.78       12.64
# 603727  sh603727  20.81       29.97
# 300567  sz300567  19.92       28.68
# now time is :  9.2906975566
# now time is :  9.2907978902
# now time is :  9.2908986207
# now time is :  9.2909986668
# now time is :  9.2910987699
# now time is :  9.2911990208
# now time is :  9.2912990704
# now time is :  9.2913998884
# now time is :  9.2915007844
# now time is :  9.2916008965
# now time is :  9.2917010159
# now time is :  9.2918010738
# now time is :  9.2919011724
# now time is :  9.2920012992
# now time is :  9.2921015344
# now time is :  9.2922016751
# now time is :  9.2923017455
# now time is :  9.2924018026
# now time is :  9.2925019306
# now time is :  9.2926020073
# now time is :  9.29270207
# now time is :  9.2928022295
# now time is :  9.2929023797
# now time is :  9.2930024371
# now time is :  9.2931024965
# now time is :  9.2932026084
# now time is :  9.2933027235
# now time is :  9.2934028105
# ...
