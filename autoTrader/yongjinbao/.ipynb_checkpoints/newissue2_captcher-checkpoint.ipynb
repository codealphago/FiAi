# %%
# coding: utf-8
import tushare as ts
import easytrader as trade
from easytrader import helpers
import pandas as pd
import datetime as dt
import time
from mercury import utils
from mercury import uqer
pd.options.display.max_columns = 100
pd.options.display.max_rows = 300

#优矿token token ='5fa4680adf1c779e93f1d90880b4e2f55a52a7704f2408565ca8c12eebba0469'
#sess = uqer.Client(token='5fa4680adf1c779e93f1d90880b4e2f55a52a7704f2408565ca8c12eebba0469')

yjb = trade.use('yjb')
yjb.prepare('./guojin.json')

## 获取资产情况 
balance = yjb.balance
## 获取股票持仓
position = yjb.position
balance
# Out:
# 2016-11-21 09:12:42,104 [DEBUG] yjbtrader.py 56: verify code detect result: 3965
# 2016-11-21 09:12:42,178 [DEBUG] yjbtrader.py 77: login response: {"login_type":"stock","returnJson":"{function_id: '200', redirect_url: '..\/main.jsp', msg_info: '', msg_no: '0', error_grids: '', grid_count: '2', CSRF_Token:'LTE5MDUzNzEyOTk1ODI3OTU5MTctMjUwOTA1Mzg5NTE4MzUwOTIxOQ==', Func200: [{company_name: '公司名称', init_date: '发生日期', sys_status: '系统状态', content_type: '帐号校验方式', account_content: '输入内容', branch_no: '客户网点', client_id: '客户号', client_name: '客户姓名', corp_client_group: '', fundaccount_count: '资产账号个数', fund_account: '资金帐号', client_rights: '客户权限', sysnode_id: '', message_flag: '消息标志', user_token: '', last_login_date: '', last_login_time: '', last_op_entrust_way: '上次登陆委托方式', last_op_station: '上次登陆站点\/电话', error_no: '错误号', error_info: '错误原因', money_count: '币种个数', money_type: '币种', square_flag: '结算标示', enable_balance: '可用金额', current_balance: '当前余额', bank_no: '银行代码', exchange_type: '交易类别', stock_account: '证券账号', bank_trans_flag: '银行转帐允许标志', initpasswd_flag: '初始密码标志', last_date: '上一交易日', last_op_ip: '上次登陆IP地址', online_time: '在线时间', remark: '摘要', tabconfirm_flag: '强制帐单确认', prestore_info: '', login_times: '登录次数', asset_prop: '', product_flag: '', corp_risk_level: '', corp_end_date: '', valid_flag: '', session_no: '', foreign_flag: '', branch_name: '', next_token: '', safety_devbound: '', safety_device_bound: '', safety_restricted_action: '', safety_restricted_info: '', alert_info: '', asset_type: '资产账号类别', password_errors: '', F800_auth_id: '', F800_en_resource_no: '', F800_en_resource_str: '', F800_app_user_id: '', F800_grantticket_id: '', F800_warn_no: '', F800_warn_info: '', F800_last_region_name: '', UserParam2: '', UserParam1: '', login_date: '上次登录日期', login_time: '上次登录时刻'},{company_name: '国金证券股份有限公司', init_date: '20161121', sys_status: '1', content_type: '0', account_content: '', branch_no: '33', client_id: '40533476', client_name: '徐雷明', corp_client_group: '1', fundaccount_count: '0', fund_account: '40533476', client_rights: 'CWdetabo', sysnode_id: '2', message_flag: '0', user_token: '6hAPsE41\/63MGLBR2hMjJlG3rZYlBogUeH5+', last_login_date: '20161118', last_login_time: '140753', last_op_entrust_way: '无线委托', last_op_station: 'PC,LIP:192.168.31.150;IIP:124.126.183.43;MAC:681729E17A9E;HD:DWW-DXE133WSPS;PCN:DELL-RAY;CPU:bfebfbff000306a9-GenuineIntel;PI:C:,NTFS,100G@TDXPC;CliVer:7.16.0', error_no: '0', error_info: '', money_count: '1', money_type: '0', square_flag: '2', enable_balance: '23455.87', current_balance: '0.50', bank_no: '7', exchange_type: '0', stock_account: '', bank_trans_flag: ' ', initpasswd_flag: ' ', last_date: '0', last_op_ip: ' ', online_time: '0', remark: ' ', tabconfirm_flag: ' ', prestore_info: ' ', login_times: '1013', asset_prop: '0', product_flag: '0', corp_risk_level: '4', corp_end_date: '20170518', valid_flag: '0', session_no: '0', foreign_flag: ' ', branch_name: '', next_token: '0', safety_devbound: '0000', safety_device_bound: '0000', safety_restricted_action: '0000', safety_restricted_info: '<ETX><ETX><ETX><ETX>', alert_info: '', asset_type: '0', password_errors: '-1', F800_auth_id: '', F800_en_resource_no: '', F800_en_resource_str: '', F800_app_user_id: '', F800_grantticket_id: '', F800_warn_no: '', F800_warn_info: '', F800_last_region_name: '', UserParam2: '2', UserParam1: '6hAPsE41\/63MGLBR2hMjJlG3rZYlBogUeH5+', login_date: '20161118', login_time: '140753'}], end: '0' }"}
# [{'asset_balance': 265587.42,
#   'current_balance': 0.5,
#   'enable_balance': 23455.87,
#   'market_value': 242131.52,
#   'money_type': '人民币',
#   'pre_interest': '1.630'}]

# %%
file_name = 'newissue2.csv'  
newissue = pd.DataFrame()

newissue = newissue.from_csv(file_name,parse_dates = False)
newissue.index = newissue.ticker.apply(lambda x:x[2:8]).values
newissue['open_price'] = newissue.price.apply(lambda x: round(x * 1.1,2))
print(newissue)

def delayrun(): # 线程运行函数 
    for s in newissue.index:
        print(s,newissue.loc[s,'open_price'], 100)
        info = yjb.buy(s, price=newissue.loc[s,'open_price'], amount=100)
        print (info)        
# t = Timer(timer_interval,delayrun)  
# t.start()  
#while (f_time >= 9.15 and f_time <= 10.30) :  
icount = 0 
flag = True
while icount < 2 and flag == True:
    c_time = dt.datetime.now().strftime('%H.%M%S%f')
    f_time = float(c_time)
    print ("now time is : " , f_time)
    if f_time > 9.1503 :
        flag = False
    elif f_time >= 9.1457 : 
        delayrun()
        icount += 1
    time.sleep(2) 

print('Market is closed...' ,dt.datetime.now() )
# Out:
#           ticker  price  open_price
# 603858  sh603858  80.47       88.52
# 002820  sz002820  23.90       26.29
# 002821  sz002821  43.96       48.36
# now time is :  9.1317433369
# now time is :  9.1318433981
# now time is :  9.1319434914
# now time is :  9.1320435721
# now time is :  9.1321450032
# now time is :  9.1322460505
# now time is :  9.1323461471
# now time is :  9.1324462166
# now time is :  9.132546288
# now time is :  9.1326470746
# now time is :  9.1327472912
# now time is :  9.1328473906
# now time is :  9.1329475375
# now time is :  9.133048181
# now time is :  9.1331484716
# now time is :  9.1332492003
# now time is :  9.1333493496
# now time is :  9.1334502496
# now time is :  9.1335512377
# now time is :  9.1336523008
# now time is :  9.1337533142
# now time is :  9.1338535092
# now time is :  9.1339542918
# now time is :  9.1340544571
# now time is :  9.1341553785
# now time is :  9.1342554961
# now time is :  9.134355564
# now time is :  9.1344557076
# now time is :  9.1345563723
# now time is :  9.1346574532
# now time is :  9.1347584542
# now time is :  9.1348585664
# now time is :  9.1349586423
# now time is :  9.135059467
# now time is :  9.1351595496
# now time is :  9.135259642
# now time is :  9.1353605261
# now time is :  9.1354606343
# now time is :  9.1355607036
# now time is :  9.1356608082
# now time is :  9.135760916
# now time is :  9.1358616052
# now time is :  9.1359616767
# now time is :  9.1400617516
# now time is :  9.1401618457
# now time is :  9.1402619544
# now time is :  9.1403620621
# now time is :  9.1404636803
# now time is :  9.1405638009
# now time is :  9.1406647126
# now time is :  9.1407648585
# now time is :  9.1408649357
# now time is :  9.1409650015
# now time is :  9.1410651081
# now time is :  9.1411651878
# now time is :  9.1412652747
# now time is :  9.1413653917
# now time is :  9.1414654851
# now time is :  9.1415655547
# now time is :  9.1416656324
# now time is :  9.14176571
# now time is :  9.1418657973
# now time is :  9.1419658743
# now time is :  9.1420659476
# now time is :  9.1421660264
# now time is :  9.1422660998
# now time is :  9.1423662112
# now time is :  9.142466291
# now time is :  9.1425663878
# now time is :  9.1426664576
# now time is :  9.1427664771
# now time is :  9.1428665695
# now time is :  9.142966678
# now time is :  9.143067089
# now time is :  9.1431672481
# now time is :  9.1432673805
# now time is :  9.1433675028
# now time is :  9.1434691249
# now time is :  9.1435691972
# now time is :  9.1436692938
# now time is :  9.1437702059
# now time is :  9.1438703131
# now time is :  9.1439711947
# now time is :  9.1440712962
# now time is :  9.1441713984
# now time is :  9.14427148
# now time is :  9.1443715898
# now time is :  9.1444722914
# now time is :  9.144573357
# now time is :  9.1446735538
# now time is :  9.1447743063
# now time is :  9.1448744533
# now time is :  9.1449753479
# now time is :  9.1450755376
# now time is :  9.1451756055
# now time is :  9.1452757317
# now time is :  9.145375839
# now time is :  9.1454758959
# now time is :  9.1455774592
# 603858 88.52 100
# {'init_date': '20161121', 'entrust_type': '0', 'error_no': '0', 'entrust_price': 88.52, 'entrust_status': '1', 'error_info': '', 'seat_no': '28356', 'batch_no': '5852', 'report_no_old': '2611', 'order_id': '2611', 'entrust_amount': 100, 'fund_account': '40533476', 'stock_code': '603858', 'report_no': '2611', 'entrust_no': '5852', 'entrust_bs': '1', 'orig_order_id': '2611', 'entrust_time': '91457'}
# 002820 26.29 100
# {'init_date': '20161121', 'entrust_type': '0', 'error_no': '0', 'entrust_price': 26.29, 'entrust_status': '1', 'error_info': '', 'seat_no': '394232', 'batch_no': '5856', 'report_no_old': '3015', 'order_id': '3015', 'entrust_amount': 100, 'fund_account': '40533476', 'stock_code': '002820', 'report_no': '3015', 'entrust_no': '5856', 'entrust_bs': '1', 'orig_order_id': '3015', 'entrust_time': '91457'}
# 002821 48.36 100
# {'init_date': '20161121', 'entrust_type': '0', 'error_no': '0', 'entrust_price': 48.36, 'entrust_status': '1', 'error_info': '', 'seat_no': '394232', 'batch_no': '5858', 'report_no_old': '3017', 'order_id': '3017', 'entrust_amount': 100, 'fund_account': '40533476', 'stock_code': '002821', 'report_no': '3017', 'entrust_no': '5858', 'entrust_bs': '1', 'orig_order_id': '3017', 'entrust_time': '91457'}
# now time is :  9.1457225126
# 603858 88.52 100
# {'report_no_old': '', 'error_no_src': '251006', 'report_no': '', 'error_no': '-61', 'error_pathinfo': 'F333002() -> F2250003() -> F3250009() -> F3250000()-->AP_SECUTRADE_REPENTRUST_CHECK', 'error_info': '不能在系统杂项参数3122设定的时间内重复发送委托请求'}
# 002820 26.29 100
# {'report_no_old': '', 'error_no_src': '251006', 'report_no': '', 'error_no': '-61', 'error_pathinfo': 'F333002() -> F2250003() -> F3250009() -> F3250000()-->AP_SECUTRADE_REPENTRUST_CHECK', 'error_info': '不能在系统杂项参数3122设定的时间内重复发送委托请求'}
# 002821 48.36 100
# {'report_no_old': '', 'error_no_src': '251006', 'report_no': '', 'error_no': '-61', 'error_pathinfo': 'F333002() -> F2250003() -> F3250009() -> F3250000()-->AP_SECUTRADE_REPENTRUST_CHECK', 'error_info': '不能在系统杂项参数3122设定的时间内重复发送委托请求'}
# now time is :  9.1458410062
# 603858 88.52 100
# {'report_no_old': '', 'error_no_src': '260200', 'report_no': '', 'error_no': '-57', 'error_pathinfo': 'F333002() -> F2250003() -> F3103000()', 'error_info': '可用资金不足'}
# 002820 26.29 100
# {'init_date': '20161121', 'entrust_type': '0', 'error_no': '0', 'entrust_price': 26.29, 'entrust_status': '1', 'error_info': '', 'seat_no': '394232', 'batch_no': '5866', 'report_no_old': '3022', 'order_id': '3022', 'entrust_amount': 100, 'fund_account': '40533476', 'stock_code': '002820', 'report_no': '3022', 'entrust_no': '5866', 'entrust_bs': '1', 'orig_order_id': '3022', 'entrust_time': '91500'}
# 002821 48.36 100
# {'report_no_old': '', 'error_no_src': '260200', 'report_no': '', 'error_no': '-57', 'error_pathinfo': 'F333002() -> F2250003() -> F3103000()', 'error_info': '可用资金不足'}
# now time is :  9.1459615502
# 603858 88.52 100
# {'report_no_old': '', 'error_no_src': '260200', 'report_no': '', 'error_no': '-57', 'error_pathinfo': 'F333002() -> F2250003() -> F3103000()', 'error_info': '可用资金不足'}
# 002820 26.29 100
# {'report_no_old': '', 'error_no_src': '251006', 'report_no': '', 'error_no': '-61', 'error_pathinfo': 'F333002() -> F2250003() -> F3250009() -> F3250000()-->AP_SECUTRADE_REPENTRUST_CHECK', 'error_info': '不能在系统杂项参数3122设定的时间内重复发送委托请求'}
# 002821 48.36 100
# {'report_no_old': '', 'error_no_src': '260200', 'report_no': '', 'error_no': '-57', 'error_pathinfo': 'F333002() -> F2250003() -> F3103000()', 'error_info': '可用资金不足'}
# now time is :  9.1500845098
# 603858 88.52 100
# {'report_no_old': '', 'error_no_src': '260200', 'report_no': '', 'error_no': '-57', 'error_pathinfo': 'F333002() -> F2250003() -> F3103000()', 'error_info': '可用资金不足'}
# 002820 26.29 100
# {'init_date': '20161121', 'entrust_type': '0', 'error_no': '0', 'entrust_price': 26.29, 'entrust_status': '1', 'error_info': '', 'seat_no': '394232', 'batch_no': '5873', 'report_no_old': '3026', 'order_id': '3026', 'entrust_amount': 100, 'fund_account': '40533476', 'stock_code': '002820', 'report_no': '3026', 'entrust_no': '5873', 'entrust_bs': '1', 'orig_order_id': '3026', 'entrust_time': '91502'}
# 002821 48.36 100
# {'report_no_old': '', 'error_no_src': '260200', 'report_no': '', 'error_no': '-57', 'error_pathinfo': 'F333002() -> F2250003() -> F3103000()', 'error_info': '可用资金不足'}
# now time is :  9.1502045633
# 603858 88.52 100
# {'report_no_old': '', 'error_no_src': '260200', 'report_no': '', 'error_no': '-57', 'error_pathinfo': 'F333002() -> F2250003() -> F3103000()', 'error_info': '可用资金不足'}
# 002820 26.29 100
# {'report_no_old': '', 'error_no_src': '251006', 'report_no': '', 'error_no': '-61', 'error_pathinfo': 'F333002() -> F2250003() -> F3250009() -> F3250000()-->AP_SECUTRADE_REPENTRUST_CHECK', 'error_info': '不能在系统杂项参数3122设定的时间内重复发送委托请求'}
# 002821 48.36 100
# {'report_no_old': '', 'error_no_src': '260200', 'report_no': '', 'error_no': '-57', 'error_pathinfo': 'F333002() -> F2250003() -> F3103000()', 'error_info': '可用资金不足'}
# Market is closed... 2016-11-21 09:15:03.235831
