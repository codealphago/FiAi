# %%
from mercury import utils
from mercury import uqer

# token ='5fa4680adf1c779e93f1d90880b4e2f55a52a7704f2408565ca8c12eebba0469'

sess = uqer.Client(token='5fa4680adf1c779e93f1d90880b4e2f55a52a7704f2408565ca8c12eebba0469')

sess.list_notebook()

#sess.download_data('allHoldings.csv')
#sess.download_notebook('SVM-temp.ipynb')
#sess.download_notebook('FIAI/神经网络交易模型.ipynb')

# sess.list_data()
sess.backup_notebook()
# sess.backup_data()
# Out:
# Hello, there are 166 notebooks in your DataYes Mercury VM
# Name: FIAI/神经网络交易模型.ipynb
# Name: FIAI/基于二分K-means和SVR方法的统计套利策略.ipynb
# Name: FIAI/神经网络择时模型0.ipynb
# Name: FIAI/随机森林预测股价涨跌.ipynb
# Name: FIAI/随机森林探索.ipynb
# Name: FIAI/2AI-SVR预测股票开盘价 v1.0.ipynb
# Name: FIAI/机器学习法选股.ipynb
# Name: FIAI/基于高频数据的短程价格方向预测-SVM.ipynb
# Name: FIAI/SVM之玩具类(大盘预测)--机器学习一S.ipynb
# Name: FOF/通过ETF进行大类资产动态配置.ipynb
# Name: FOF/【资产配置】最小方差组合理论与实践.ipynb
# Name: FOF/1.基金指数分析.ipynb
# Name: FOF/二八轮动.ipynb
# Name: FOF/【资产配置】风险平价组合(risk parity)理论与实践.ipynb
# Name: FOF/VaR仓位管理下的低风险策略.ipynb
# Name: FOF/基于奇异谱择时的FOF动量策略.ipynb
# Name: FOF/wealthfront的资产配置方法.ipynb
# Name: 基础分析/comm.ipynb
# Name: 基础分析/0.report.ipynb
# Name: 基础分析/signal.ipynb
# Name: 基础分析/grid.ipynb
# Name: 基础分析/behavior.ipynb
# Name: 基础分析/alpha.ipynb
# Name: 基础分析/0.alpha.ipynb
# Name: 基础分析/uqer.ipynb
# Name: 基础分析/fund.ipynb
# Name: 基础分析/valuation.ipynb
# Name: 基础分析/1.个股分析.ipynb
# Name: 基础分析/tech.ipynb
# Name: 基础分析/0.beta.ipynb
# Name: 基础分析/filter.ipynb
# ...
