# %% [markdown]
# `优矿日报`
# ----
# ***
#
# ```
# 优矿提供了免费的，完整的金融数据，方便大家进行自己的投资分析，模型构建，策略研发，下面我们就看看在优矿上如何看一些常见的反应大势的重要数据。
# ```
#
# - 两融数据
# - 沪股通数据
# - 港股通数据
# - 大宗交易
# - 大盘资金流入流出 [ `特大单，大单，中单，小单情况` ] 情况
# - 板块涨跌分布
# - 期权日报
# - 行业资金流入流出 [ `特大单，大单，中单，小单情况` ] 情况
# - 个股资金流入流出 [ `特大单，大单，中单，小单情况` ] 情况

# %%
# built-in
import time
import operator
import datetime as dt
import collections
from functools import wraps

# 3-party
import pandas as pd
pd.options.display.max_columns = 100
pd.options.display.max_rows = 300

import numpy as np

import seaborn
from matplotlib import pylab
import matplotlib.pyplot as plt
from matplotlib.pyplot import *

import sklearn
import sklearn.preprocessing

from CAL.PyCAL import *
font.set_size(16)

# personal lib
from lib import report

# %% [markdown]
# `融资融券`

# %%
def rong_zi_rong_quan():
    """融资融券信息
    """
    trade_days = report.trade_pre_n_days()
    data = DataAPI.FstTotalGet(exchangeCD=u"XSHE,XSHG", beginDate=trade_days[0])
    data = data.groupby(by='tradeDate').sum()
    data['tradeVal'] = data['tradeVal'] / (10**12)
    ax = data.plot(y=['tradeVal'], kind='bar', figsize=(20, 5), title=u'融资融券余额: (单位：万亿)')
    
    ax.set_ylim([0.8, 1.3])
    axhline(y=1.0, color='r')
    report.fig_style(ax, [u'两融余额'])
    
    ###
    tradeValChange = [0]
    tmp = data.tradeVal[0]
    for i in data.tradeVal[1:]:
        tradeValChange.append(i - tmp)
        tmp = i
    data['tradeValChange'] = tradeValChange
    ax = data.plot(y=['tradeValChange'], kind='bar', figsize=(20, 5), title=u'当日融资融券余额相对上一交易日变动: (单位：万亿)', color='g')
    data['tmp'] = [max(i, 0) for i in data.tradeValChange]
    data.plot(y=['tmp'], kind='bar', color='r', ax=ax)
    report.fig_style(ax, [u'两融余额变动'])
    
    return data

data = rong_zi_rong_quan()

# %% [markdown]
# 当两融余额属于收缩下降状态, 市场弱势,谨慎加仓

# %% [markdown]
# `沪港通`

# %%
def hu_gang_tong():
    """沪港通数据
    """
    trade_days = report.trade_pre_n_days()
    res, hushen, hk = pd.DataFrame(), pd.DataFrame(), pd.DataFrame()
    for day in trade_days:
        tmp_1 = DataAPI.JY.HKSHKQuotaJYGet(endDate=day, tradingTypeCd="1")
        tmp_2 = DataAPI.JY.HKSHKQuotaJYGet(endDate=day, tradingTypeCd="2")
        hushen = tmp_1 if hushen.empty else hushen.append(tmp_1) 
        hk = tmp_2 if hk.empty else hk.append(tmp_2) 
    
    hushen['netIn'] = (hushen['dailyQuota'] - hushen['dailiBalance']) / (10 ** 9)
    hk['netIn'] = (hk['dailyQuota'] - hk['dailiBalance']) / (10 ** 9)
    res['tradeDate'], res['in_hushen'] = hushen['endDate'], hushen['netIn']
    res['in_hk'] = hk[hk.endDate.isin(hushen.endDate)].netIn        # 沪股通缺失2015-12-24的数据
    
    ### plot
    res.tradeDate = [i[:10] for i in res.tradeDate.values]          # 时间格式转换
    ax = res.plot(x='tradeDate', y=['in_hushen'], kind='bar', figsize=(20, 4), title=u'沪股通净流入流出 (单位：十亿)', color='g')
    res['tmp'] = [max(i, 0) for i in res.in_hushen]
    res.plot(x='tradeDate', y=['tmp'], kind='bar', color='r', ax=ax)
    report.fig_style(ax, [u'沪股通净流入'])

    ax = res.plot(x='tradeDate', y=['in_hk'], kind='bar', figsize=(20, 4), title=u'港股通净流入流出 (单位：十亿)', color='g')
    res['tmp'] = [max(i, 0) for i in res.in_hk]
    res.plot(x='tradeDate', y=['tmp'], kind='bar', color='r', ax=ax)
    report.fig_style(ax, [u'港股通净流入'])
    
    return hushen, hk

hushen, hk = hu_gang_tong()

# %% [markdown]
# 沪股通叫均衡处于流入流出平衡状态,但是交易不活跃,  港股处于持续流入状态, 应该在某一点开始有量变过程.

# %% [markdown]
# `大宗交易`

# %%
def dazong_jiaoyi():
    """大宗交易
    """
    trade_days = report.trade_pre_n_days()
    data = DataAPI.MktBlockdGet(secID=set_universe('A'), beginDate=trade_days[0], endDate=trade_days[-1], 
                                assetClass=u"E", field=['tradeDate', 'ticker','tradeVol','secFullName','tradePrice'])
    stocklist = data.groupby(['tradeDate','ticker','secFullName','tradePrice']).sum()
    print(u'最近10笔大于1000手的大宗交易：')
    print(stocklist.loc[stocklist.tradeVol>1000].tail(10))
    data = data.groupby('tradeDate').sum()
    data.tradeVol = data.tradeVol / (10 ** 4)
    ax = data.plot(y=['tradeVol'], kind='bar', figsize=(20, 6), title=u'每日大宗交易量: (单位: 万手)')
    report.fig_style(ax, [u'大宗交易量'])
   
    return data

data = dazong_jiaoyi()
# Out:
# 最近10笔大于1000手的大宗交易：
#                                            tradeVol
# tradeDate  ticker secFullName tradePrice
# 2016-01-20 600745 中茵股份        28.51       1454.8000
# 2016-01-21 002624 完美环球        25.44       1336.2200
# 2016-01-22 000670 盈方微         9.57        4000.0000
#            600577 精达股份        4.01        1100.0000
#            600610 中毅达         14.80       2000.0000
#            601006 大秦铁路        6.60        1212.4147
# 2016-01-25 002005 德豪润达        6.43        2300.0000
#            002132 恒星科技        6.40        1590.0000
#            600346 大橡塑         9.97        1500.0000
#            601991 大唐发电        4.64        7000.0000

# %% [markdown]
# 大宗交易比较平稳,每日小于一万手是安全区间.  留意大宗交易个股成交量和成交价

# %% [markdown]
# `大盘资金流入流出情况`

# %%
def money_flow():
    """资金流入流出情况
    """
    trade_days = report.trade_pre_n_days()
    data = pd.DataFrame()
    for day in trade_days:
        tmp = DataAPI.MktIndustryFlowOrderGet(tradeDate=day)
        data = tmp if data.empty else data.append(tmp)
    data.netInflowS, data.netInflowM = data.netInflowS / (10**9), data.netInflowM/ (10**9)
    data.netInflowL, data.netInflowXl = data.netInflowL / (10**9), data.netInflowXl/ (10**9)
    data = data.groupby('tradeDate').sum()
    ax = data.plot(y=['netInflowS', 'netInflowM', 'netInflowL', 'netInflowXl'], kind='bar', figsize=(20, 8), title=u'每日资金净流入流出情况: (单位: 亿)')
    report.fig_style(ax, [u'小单', u'中单', u'大单', u'特大单'], 'upper right')
    
    return data

data = money_flow()

# %% [markdown]
# 主要看大单和超大单流入情况

# %% [markdown]
# `板块涨跌情况`

# %%
def industry_change():
    """行业涨跌平均涨幅
    """
    trade_days = report.trade_pre_n_days()
    data = DataAPI.MktEqudGet(tradeDate=trade_days[-1], secID=set_universe('A'), 
                              field=['secID', 'ticker', 'preClosePrice', 'closePrice', 'tradeDate'])
    if data.empty:
        data = DataAPI.MktEqudGet(tradeDate=trade_days[-2], secID=set_universe('A'), 
                                  field=['secID', 'ticker', 'preClosePrice', 'closePrice', 'tradeDate'])
    print("Trade Date is : ", trade_days[-1])
    data['up_ratio'] = data['closePrice'] - data['preClosePrice']
    data['is_up'] = [1 if i>=0 else 0 for i in data.up_ratio]
    data['is_down'] = [1 if i<0 else 0 for i in data.up_ratio]
    
    industry_ticker = DataAPI.EquIndustryGet(secID=set_universe('A'),
                                             field=['ticker', 'secID', 'secShortName', 'industryName2', 'industryName1','isNew', 'industry'])
    industry_ticker = industry_ticker[(industry_ticker.isNew == 1) & (industry_ticker.industry == '申万行业分类')]
    
    data = data.merge(industry_ticker[['ticker', 'secShortName', 'industryName2', 'industryName1']], on=['ticker'])
    
    industry2 = data.groupby('industryName2')
    
    ### plot avg ratio     
    fig = industry2.mean()
    fig = fig.sort(columns=['up_ratio'])
    tmp = fig.head(10).append(fig.tail(10))
    ax = tmp.plot(y=['up_ratio'], kind='bar', figsize=(20, 6), title=u'申万二级行业平均涨幅')
    tmp['tmp'] = [max(i, 0) for i in tmp.up_ratio]
    tmp.plot(y=['tmp'], kind='bar', color='r', ax=ax)
    
    for label in ax.get_xticklabels(): 
        label.set_fontproperties(font) 
    report.fig_style(ax, [u'行业平均涨幅'])
    
    ### plot up and down 
    fig = industry2.sum()
    fig['industry'] = fig.index.values
    fig = fig[fig.industry.isin(tmp.index.values)]
    fig.up_ratio = fig.up_ratio / (fig.is_up + fig.is_down)
    fig = fig.sort(columns=['up_ratio'])
    ax = fig.plot(y=['is_up', 'is_down'], kind='bar', figsize=(20, 6), stacked=True, title=u'申万二级行业涨跌情况', color=['r', 'g'])
    for label in ax.get_xticklabels(): 
        label.set_fontproperties(font) 
    report.fig_style(ax, [u'上涨家数', u'下跌家数'])

    return data

data = industry_change()
# Out:
# ('Trade Date is : ', '2016-01-26')

# %% [markdown]
# `期权日报`

# %%
def optIndicators():
    trade_days = report.trade_pre_n_days()
    start, end = dt.datetime.strptime(trade_days[0], '%Y-%m-%d'), dt.datetime.strptime(trade_days[-1], '%Y-%m-%d')
    
    ### calculation
    opt_indicators = pd.DataFrame(columns=[u'成交量PCR',u'成交额PCR',u'近月PCIVD',u'次月PCIVD',u'中国波指iVIX'])
    opt_indicators[[u'成交量PCR',u'成交额PCR']] = report.histPCR50ETF(start, end)[[u'volPCR',u'valuePCR']]
    opt_indicators[[u'近月PCIVD',u'次月PCIVD']] = report.histPCIVD50ETF(start, end)[[u'nearPCIVD',u'nextPCIVD']]
    opt_indicators[u'中国波指iVIX'] = report.getHistDailyVIX(start, end).iVIX/100.0
    opt_indicators.index = [str(i)[:10] for i in opt_indicators.index.values]
    opt_indicators.index.name = 'tradeDate'
    
    ### plot
    ax = opt_indicators.plot(y=[u'近月PCIVD', u'次月PCIVD', u'中国波指iVIX'], figsize=(20, 6), title=u'看跌期权隐含波动率 - 看涨期权隐含波动率')
    report.fig_style(ax, [u'近月PCIVD', u'次月PCIVD', u'中国波指iVIX'])

    ax = opt_indicators.plot(y=[u'成交量PCR', u'成交额PCR'], figsize=(20, 6), title=u'看跌期权成交量成交额 / 看涨期权成交量成交额')
    report.fig_style(ax, [u'成交量PCR', u'成交额PCR'])

    return opt_indicators

data = optIndicators()

# %% [markdown]
# `行业资金流入流出`

# %%
def industry_money_flow():
    """行业资金流
    """
    trade_days = report.trade_pre_n_days()
    preTradeDate = trade_days[-2]
    data = DataAPI.MktIndustryFlowOrderGet(tradeDate=preTradeDate.replace('-', ''), 
                                           field=['industryName', 'netInflowS', 'netInflowM', 'netInflowL', 'netInflowXl'])
    tmp = DataAPI.MktIndustryFlowGet(tradeDate=preTradeDate, field=['industryName', 'moneyInflow', 'moneyOutflow', 'netMoneyInflow'])
    data = data.merge(tmp, on=['industryName'])
    
    data['zhuli'] = data.netInflowL + data.netInflowXl    
    data.sort(columns=['netMoneyInflow', 'zhuli'], ascending=[0, 0], inplace=True)
    res = data[['industryName', 'netMoneyInflow', 'zhuli']]
    res.columns = [u'行业名称', u'资金净流入', u'大单，特大单净流入']
    return res.head(12)

data = industry_money_flow()
data
# Out:
#                 行业名称         资金净流入   大单，特大单净流入
# 58  计算机、通信和其他电子设备制造业  9.919283e+09  9224992324
# 46        电气机械和器材制造业  5.009315e+09  4968921720
# 61        软件和信息技术服务业  3.462484e+09  4110473372
# 1            专用设备制造业  3.358810e+09  3215734316
# 15             医药制造业  2.300775e+09  2129646752
# 62           通用设备制造业  2.047593e+09  1904437644
# 39             汽车制造业  1.941817e+09  2023911585
# 32      有色金属冶炼和压延加工业  1.931204e+09  1844648064
# 70          非金属矿物制品业  1.920274e+09  1709182681
# 73      黑色金属冶炼和压延加工业  1.687170e+09  1669209706
# 4            仪器仪表制造业  1.405314e+09  1431133948
# 25              房地产业  1.385355e+09   816896175

# %% [markdown]
# `个股资金流入流出`

# %%
def ticker_money_flow():
    """个股资金流
    """
    trade_days = report.trade_pre_n_days()
    preTradeDate = trade_days[-2]
    all_ticker = report.get_all_ticker(preTradeDate)
    data = DataAPI.MktEquFlowOrderGet(secID=set_universe("A"), beginDate=preTradeDate, endDate=preTradeDate, 
                                      field=['ticker', 'secID', 'netInflowS', 'netInflowM', 'netInflowL', 'netInflowXl'])
    tmp = DataAPI.MktEquFlowGet(tradeDate=preTradeDate, field=['ticker', 'secID', 'moneyInflow', 'moneyOutflow', 'netMoneyInflow'])
    data = data.merge(tmp, on=['secID', 'ticker'])
    
    data['zhuli'] = data.netInflowL + data.netInflowXl
    data = data.merge(all_ticker, on=['ticker', 'secID'])
    data.sort(columns=['netMoneyInflow', 'zhuli'], ascending=[0, 0], inplace=True)
    res = data[['ticker', 'secID', 'secShortName', 'marketValue', 'totalShares', 'netMoneyInflow', 'zhuli']]
    res.columns = ['ticker', 'secID', u'中文简称', u'总市值', u'总股本', u'资金净流入', u'大单，特大单净流入']
    
    return res.head(12)

ticker_money_flow()
# Out:
#       ticker        secID  中文简称          总市值          总股本         资金净流入  \
# 756   002292  002292.XSHE  奥飞动漫  45730761845   1264328500  9.102229e+08
# 451   000983  000983.XSHE  西山煤电  23570976000   3151200000  8.823036e+08
# 1603  300364  300364.XSHE  中文在线  13308000000    120000000  8.507754e+08
# 1210  002751  002751.XSHE  易尚展示  15405036800    140480000  6.613079e+08
# 354   000851  000851.XSHE  高鸿股份   7433449251    591364300  6.297756e+08
# 930   002466  002466.XSHE  天齐锂业  32341100610    261469000  6.145649e+08
# 413   000932  000932.XSHE  华菱钢铁  11640409386   3015650100  5.760977e+08
# 737   002273  002273.XSHE  水晶光电  14604671400    436612000  5.595935e+08
# 258   000709  000709.XSHE  河北钢铁  34935219662  10618607800  5.151525e+08
# 2059  600383  600383.XSHG  金地集团  69293992460   4499609900  5.070488e+08
# 819   002355  002355.XSHE  兴民钢圈  11809965299    513700100  5.024645e+08
# 1704  300466  300466.XSHE  赛摩电气   6106400000     80000000  4.877753e+08
#
#          大单，特大单净流入
# 756   5.312212e+08
# 451   8.490680e+08
# 1603  7.310527e+08
# 1210  6.338716e+08
# 354   5.173955e+08
# 930   6.691477e+08
# 413   5.193849e+08
# 737   5.399802e+08
# 258   5.056956e+08
# 2059  1.687572e+08
# 819   3.632528e+08
# 1704  4.924151e+08

# %% [markdown]
# `相关 report 包代码会单独分享`
