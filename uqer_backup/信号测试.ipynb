# %% [raw]
# import numpy as np
# import pandas as pd
# import datetime as dt
# import lib.signal as signal
# import lib.comm as comm
#
# start = '2015-01-01'                       # 回测起始
# today = comm.getPrevBusinessDay(dt.date.today(),1)
# end = today.strftime('%Y-%m-%d')                 #最近交易日
# #end = '2015-06-01'                          #回测结束时间
#
# commission = Commission(buycost=0.0003, sellcost=0.0013)  # 佣金万八
# capital_base = 100000                      # 起始资金10W
# freq = 'd'                              # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 1                        # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# benchmark = 'HS300'                       # 策略参考标准
# universe =  ['510300.XSHG']
#
# def initialize(account):                   # 初始化虚拟账户状态
#    pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#
#     adj_date = account.previous_date
#     #mysig = signal.getActivateSignal(signal.ALL,adj_date).sig20[-1]
#     mysig = signal.getShiborSignal('1W',adj_date).signal[-1]
#     if mysig == False :
#         order_to(account.universe[0], 0)
#     else  :
#         order_pct_to(account.universe[0], 1)
