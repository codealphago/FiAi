# %% [markdown]
# 成交额（成交量）小，表明这个股票无人关注，所以它的价格也是比较低的，买入后，放上一段时间，大概率上涨。
# 这个策略的买入逻辑是：
# 1、买入市场上前20个交易日成交额最小的20支股票。
# 2、每个月满仓轮换。
# 2011~2016年间取得了161%的正收益。
# 十年取得50回报。（当然这个结果有可能会有生存都偏差）
# 代码里，我用到了一些pandas的技法，可以极大地减少代码量，各位可以参考，希望能够帮助大家~

# %% [raw]
# import numpy as np
# import pandas as pd
#
# start = '2010-03-01'                       # 回测起始时间
# end = '2016-09-28'                         # 回测结束时间
# benchmark = 'HS300'                        # 策略参考标准
# universe =  set_universe('HS300')   #DynamicUniverse('HS300')#StockScreener(Factor.LCAP.nsmall(100))#set_universe('HS300')           # 证券池，支持股票和基金
# capital_base = 1000000                      # 起始资金
# freq = 'd'                                 # 策略类型，'d'表示日间策略使用日线回测，'m'表示日内策略使用分钟线回测
# refresh_rate = 60                          # 调仓频率，表示执行handle_data的时间间隔，若freq = 'd'时间间隔的单位为交易日，若freq = 'm'时间间隔为分钟
#
# def initialize(account):                   # 初始化虚拟账户状态
#     pass
#
# def handle_data(account):                  # 每个交易日的买入卖出指令
#     data = account.get_attribute_history('turnoverValue', 20)
#     df = pd.DataFrame(pd.DataFrame(data).mean())
#     df = df[df[0] > 10000].sort(columns=0).head(40) #把成交量过小的去掉
#
#     for stock in account.security_position:
#         order_to(stock, 0)
#
#     for stock in df.index:
#         if account.cash < 0:
#             break
#         try:
#             order_pct_to(stock, 0.05)#平均购买20支
#         except:
#             pass
